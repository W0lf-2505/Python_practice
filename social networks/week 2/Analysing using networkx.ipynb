# %%
import networkx as nx

# %%
G = nx.read_edgelist('../facebook_combined.txt')

# %%
print(G)
# Out:
# Graph with 4039 nodes and 88234 edges

# %%
print(G.is_directed())
# Out:
# False

# %%
print(G.number_of_nodes())
print(G.number_of_edges())
# Out:
# 4039
# 88234

# %%
X = nx.read_gml('../karate.gml', label=None)

# %%
nx.draw(X)

# %%
nx.draw_circular(X)

# %%
nx.draw_networkx(X)

# %%
import plot

# %%
plot.plot_deg_dist(X)

# %%
print(nx.density(G))
# Out:
# 0.010819963503439287

# %%
C = nx.complete_graph(100)

# %%
print(nx.density(C))
# Out:
# 1.0

# %%
print(nx.density(X))
# Out:
# 0.13903743315508021

# %%
for i in nx.clustering(X).items():
    print(i)
# Out:
# (1, 0.15)
# (2, 0.3333333333333333)
# (3, 0.24444444444444444)
# (4, 0.6666666666666666)
# (5, 0.6666666666666666)
# (6, 0.5)
# (7, 0.5)
# (8, 1.0)
# (9, 0.5)
# (10, 0)
# (11, 0.6666666666666666)
# (12, 0)
# (13, 1.0)
# (14, 0.6)
# (15, 1.0)
# (16, 1.0)
# (17, 1.0)
# (18, 1.0)
# (19, 1.0)
# (20, 0.3333333333333333)
# (21, 1.0)
# (22, 1.0)
# (23, 1.0)
# (24, 0.4)
# (25, 0.3333333333333333)
# (26, 0.3333333333333333)
# (27, 1.0)
# (28, 0.16666666666666666)
# (29, 0.3333333333333333)
# (30, 0.6666666666666666)
# (31, 0.5)
# (32, 0.2)
# (33, 0.19696969696969696)
# (34, 0.11029411764705882)

# %%
print(nx.diameter(X))
# Out:
# 5
