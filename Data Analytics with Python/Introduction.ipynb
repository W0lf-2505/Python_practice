# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
gap_miner_data = 'https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/refs/heads/master/data/gapminder-FiveYearData.csv'
df = pd.read_csv(gap_miner_data)
print(df.head())
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
groupdata = df.groupby('continent')['lifeExp'].nunique()
groupdata.plot()
# Out:
# <Axes: xlabel='continent'>
